# %%
import math
import random
import h5py
import folium 
import random
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
with open('testgps', 'rb') as f:
    testgps = pickle.load(f)

# %%
with open("pred_test_300_neutraj_128", "rb") as f:
    pred_test_300_neutraj_128 = pickle.load(f)

# %%
with open("clusters", "rb") as f:
    clusters = pickle.load(f)

# %%
meanGPS = clusters['meanGPS']
print(len(meanGPS))
# Out:
# 97

# %%
my_map = folium.Map(location = [testgps[1000][0][1], testgps[1000][-1][0]], zoom_start = 15, 
                    tiles='https://mt.google.com/vt/lyrs=m&x={x}&y={y}&z={z}', attr='default')#, tiles = 'https://{s}.tile-cyclosm.openstreetmap.fr/cyclosm/{z}/{x}/{y}.png', attr= 'default')

for i in range(len(testgps[1000])):
    folium.Circle( radius = 25,
                        location=[testgps[1000][i][1],testgps[1000][i][0]],
                        color='blue',
                        opacity = 1,
                        fill=True,
                        fill_opacity = 1
                        ).add_to(my_map)

folium.PolyLine(testgps[1000][:,[1,0]], color="blue",lineCap='round', weight=5, opacity=0.6).add_to(my_map)

for id in range(len(meanGPS)):
    folium.Circle( radius = 100,
                            location=[meanGPS[id][1],meanGPS[id][0]],
                            color='red',
                            opacity = 1,
                            fill=False,
                            fill_opacity = 1
                            ).add_to(my_map)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# 绘制实际轨迹和预测轨迹，红色为实际轨迹，绿色为预测轨迹

# 选定轨迹编号
trj_choose = 1000

# my_map = folium.Map(location=[trg_trj[0][0],trg_trj[-1][1]], zoom_start=14)
my_map = folium.Map(location = [testgps[trj_choose][0][1], testgps[trj_choose][-1][0]], zoom_start = 15, 
                    tiles='https://mt.google.com/vt/lyrs=m&x={x}&y={y}&z={z}', attr='default')#, tiles = 'https://{s}.tile-cyclosm.openstreetmap.fr/cyclosm/{z}/{x}/{y}.png', attr= 'default')

for i in range(len(testgps[trj_choose])):
    folium.Circle( radius = 25,
                        location=[testgps[trj_choose][i][1],testgps[trj_choose][i][0]],
                        color='blue',
                        opacity = 1,
                        fill=True,
                        fill_opacity = 1
                        ).add_to(my_map)

for i in range(len(pred_test_300_neutraj_128[trj_choose])):
    if(pred_test_300_neutraj_128[trj_choose][i]==1):
        folium.Circle( radius = 100,
                        location=[meanGPS[i][1],meanGPS[i][0]],
                        color='red',
                        opacity = 1,
                        fill=False,
                        fill_opacity = 0.4
                        ).add_to(my_map)
# for i in range(len(pre_trj)):
#     folium.Circle( radius = 10,
#                         location=[pre_trj[i][0],pre_trj[i][1]],
#                         color='green',
#                         opacity = 1,
#                         fill=True,
#                         fill_opacity = 1
#                         ).add_to(my_map)

folium.PolyLine(testgps[trj_choose][:,[1,0]], color='blue',lineCap='round', weight=5, opacity=0.6).add_to(my_map)
# folium.Marker(trg_trj[0], popup='<b>Starting Point</b>').add_to(my_map)
# folium.PolyLine(pre_trj, color="green", weight=15, opacity=1).add_to(my_map)
my_map.save('a.html')
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
with open('testgps', 'rb') as f:
    testgps = pickle.load(f)

# %%
with open("pred_test_300_t2vec_128", "rb") as f:
    pred_test_300_t2vec_128 = pickle.load(f)

# %%
with open("clusters", "rb") as f:
    clusters = pickle.load(f)

# %%
meanGPS = clusters['meanGPS']

# %%
# 绘制实际轨迹和预测轨迹，红色为实际轨迹，绿色为预测轨迹

# 选定轨迹编号
trj_choose = 1000

# my_map = folium.Map(location=[trg_trj[0][0],trg_trj[-1][1]], zoom_start=14)
my_map = folium.Map(location = [testgps[trj_choose][0][1], testgps[trj_choose][-1][0]], zoom_start = 15)

for i in range(len(testgps[trj_choose])):
    folium.Circle( radius = 25,
                        location=[testgps[trj_choose][i][1],testgps[trj_choose][i][0]],
                        color='cornflowerblue',
                        opacity = 1,
                        fill=True,
                        fill_opacity = 1
                        ).add_to(my_map)

for i in range(len(pred_test_300_t2vec_128[trj_choose])):
    if(pred_test_300_t2vec_128[trj_choose][i]==1):
        folium.Circle( radius = 100,
                        location=[meanGPS[i][1],meanGPS[i][0]],
                        color='red',
                        opacity = 0.6,
                        fill=True,
                        fill_opacity = 0.4
                        ).add_to(my_map)
# for i in range(len(pre_trj)):
#     folium.Circle( radius = 10,
#                         location=[pre_trj[i][0],pre_trj[i][1]],
#                         color='green',
#                         opacity = 1,
#                         fill=True,
#                         fill_opacity = 1
#                         ).add_to(my_map)

folium.PolyLine(testgps[trj_choose][:,[1,0]], color='cornflowerblue',lineCap='round', weight=10, opacity=0.6).add_to(my_map)
# folium.Marker(trg_trj[0], popup='<b>Starting Point</b>').add_to(my_map)
# folium.PolyLine(pre_trj, color="green", weight=15, opacity=1).add_to(my_map)
my_map.save('t2vec.html')
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
