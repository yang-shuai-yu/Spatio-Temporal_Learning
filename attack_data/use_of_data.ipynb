# %%
import pickle

# %%
# 这是用来做聚类训练的数据
with open("embeddings/t2vec/256/t2vec_train", "rb") as f:
    t2vecEmbed = pickle.load(f)

clusterUsed = t2vecEmbed[0:100000]
with open("/home/yangshuaiyu6791/RepresentAttack/xsc/clustering/t2vec_256", "wb") as f:
    pickle.dump(clusterUsed, f)

# %%
with open('gps_seqs/traingps', 'rb') as f:
    traingps = pickle.load(f)
with open('gps_seqs/valgps', 'rb') as f:
    valgps = pickle.load(f)
with open('gps_seqs/testgps', 'rb') as f:
    testgps = pickle.load(f)
# 上面都是gps轨迹文件
with open('cell_seqs/t2vec_partition/traincell', 'rb') as f:
    traincell = pickle.load(f)
with open('cell_seqs/t2vec_partition/valcell', 'rb') as f:
    valcell = pickle.load(f)
with open('cell_seqs/t2vec_partition/testcell', 'rb') as f:
    testcell = pickle.load(f)
# 上面都是cell sequence轨迹文件

# %%
print(len(traingps), len(traincell), len(valgps), len(valcell), len(testgps), len(testcell))
# Out:
# 180000 180000 10000 10000 10000 10000

# %%
print(testgps[0])
print(traincell[0])
# Out:
# [[-8.574984 41.166054]
#  [-8.574975 41.166072]
#  [-8.574975 41.166081]
#  [-8.575263 41.166414]
#  [-8.576262 41.166414]
#  [-8.576316 41.165892]
#  [-8.576793 41.165316]
#  [-8.577063 41.165451]
#  [-8.577639 41.165766]
#  [-8.578548 41.165046]
#  [-8.579466 41.164245]
#  [-8.581104 41.164416]
#  [-8.582247 41.165181]
#  [-8.583282 41.166225]
#  [-8.585874 41.166783]
#  [-8.58843  41.167935]
#  [-8.591094 41.169528]
#  [-8.593632 41.171247]
#  [-8.596566 41.171886]
#  [-8.599311 41.171418]
#  [-8.602119 41.171625]
#  [-8.604063 41.172615]
#  [-8.604612 41.172165]
#  [-8.604603 41.171427]
#  [-8.605008 41.170914]
#  [-8.60616  41.169474]
#  [-8.606511 41.167872]
#  [-8.606565 41.167296]
#  [-8.606502 41.16726 ]
#  [-8.606475 41.167152]
#  [-8.606754 41.166504]
#  [-8.608329 41.166612]
#  [-8.610219 41.166801]
#  [-8.610795 41.167044]
#  [-8.610984 41.167512]
#  [-8.611281 41.167296]
#  [-8.611425 41.167152]
#  [-8.611578 41.166558]
#  [-8.612514 41.166504]
#  [-8.614017 41.166972]
# ...

# %%
print(valgps[0])
print(valcell[0])
# Out:
# [[-8.621379 41.156028]
#  [-8.621379 41.156028]
#  [-8.621388 41.156019]
#  [-8.621136 41.155785]
#  [-8.621064 41.155722]
#  [-8.619948 41.155425]
#  [-8.618724 41.155164]
#  [-8.618706 41.155173]
#  [-8.618724 41.155155]
#  [-8.618715 41.155164]
#  [-8.618724 41.155173]
#  [-8.618715 41.1552  ]
#  [-8.618697 41.1552  ]
#  [-8.618121 41.155101]
#  [-8.616024 41.154714]
#  [-8.614071 41.154354]
#  [-8.613657 41.154228]
#  [-8.613423 41.154192]
#  [-8.613288 41.153949]
#  [-8.613306 41.153958]
#  [-8.61255  41.15367 ]
#  [-8.611056 41.153562]
#  [-8.608815 41.153535]
#  [-8.607015 41.153445]
#  [-8.606196 41.152617]
#  [-8.607258 41.151591]
#  [-8.606565 41.151024]
#  [-8.604774 41.15097 ]
#  [-8.60418  41.150376]
#  [-8.604162 41.149611]
#  [-8.604126 41.14953 ]
#  [-8.605233 41.149701]
#  [-8.605566 41.149782]
#  [-8.605728 41.149773]]
# [ 428  493  329  208  835  849  631   88   60  229  437  260  644  317
#   654  468  396 1304  207  239]

# %%
print(testgps[0])
print(testcell[0])
# Out:
# [[-8.574984 41.166054]
#  [-8.574975 41.166072]
#  [-8.574975 41.166081]
#  [-8.575263 41.166414]
#  [-8.576262 41.166414]
#  [-8.576316 41.165892]
#  [-8.576793 41.165316]
#  [-8.577063 41.165451]
#  [-8.577639 41.165766]
#  [-8.578548 41.165046]
#  [-8.579466 41.164245]
#  [-8.581104 41.164416]
#  [-8.582247 41.165181]
#  [-8.583282 41.166225]
#  [-8.585874 41.166783]
#  [-8.58843  41.167935]
#  [-8.591094 41.169528]
#  [-8.593632 41.171247]
#  [-8.596566 41.171886]
#  [-8.599311 41.171418]
#  [-8.602119 41.171625]
#  [-8.604063 41.172615]
#  [-8.604612 41.172165]
#  [-8.604603 41.171427]
#  [-8.605008 41.170914]
#  [-8.60616  41.169474]
#  [-8.606511 41.167872]
#  [-8.606565 41.167296]
#  [-8.606502 41.16726 ]
#  [-8.606475 41.167152]
#  [-8.606754 41.166504]
#  [-8.608329 41.166612]
#  [-8.610219 41.166801]
#  [-8.610795 41.167044]
#  [-8.610984 41.167512]
#  [-8.611281 41.167296]
#  [-8.611425 41.167152]
#  [-8.611578 41.166558]
#  [-8.612514 41.166504]
#  [-8.614017 41.166972]
# ...

# %%
with open('embeddings/t2vec/128/t2vec_train', 'rb') as f:
    t2vec_train = pickle.load(f)
with open('embeddings/t2vec/128/t2vec_val', 'rb') as f:
    t2vec_val = pickle.load(f)
with open('embeddings/t2vec/128/t2vec_test', 'rb') as f:
    t2vec_test = pickle.load(f)
# 上面是t2vec的嵌入结果
with open('embeddings/neutraj/128/neutraj_train', 'rb') as f:
    neutraj_train = pickle.load(f)
with open('embeddings/neutraj/128/neutraj_val', 'rb') as f:
    neutraj_val = pickle.load(f)
with open('embeddings/neutraj/128/neutraj_test', 'rb') as f:
    neutraj_test = pickle.load(f)
# 上面是neutraj的嵌入结果

# %%
print(len(t2vec_train), len(t2vec_val), len(t2vec_test), len(neutraj_train), len(neutraj_val), len(neutraj_test))
# Out:
# 180000 10000 10000 180000 10000 10000

# %%
print(t2vec_train[0])
print(t2vec_val[0])
print(t2vec_test[0])
# Out:
# [-0.48271376 -0.04138878  0.02031344 -0.02523904 -0.4085901  -0.3910374
#  -0.22011086 -0.99988097 -0.01374778  0.5248991   0.9996552  -0.9878873
#   0.66963357  0.7110676   0.91960084 -0.83882457  0.60458297 -0.9997114
#  -0.9932166  -0.9949404   0.19811638 -0.65584433 -0.99645716  0.5546257
#   0.70220244 -0.9993378   0.9849946   0.8630128  -0.55113155  0.771858
#  -0.5844721   0.73809177  0.562219   -0.99999994  0.89691    -0.4639461
#   0.2590947   0.99979377  0.92606074 -0.8824211  -0.5737355  -0.99452513
#  -0.70860136 -0.9152428   0.22157048  0.78715104  0.8433311  -0.64801466
#   0.87830615  0.9688988  -0.45627135  0.9997053   0.14719427 -0.83745694
#   0.58995485 -0.05315131  0.8528894   0.07566963  0.99830073  0.96818304
#   0.22407494 -0.95860666  0.93114644 -0.11195711 -0.6883993   0.8802611
#  -0.9999773  -0.99995744  0.99736005  0.99996936  0.99940234  0.84955794
#   0.2704848  -0.6301827   0.45058215  0.91655385 -0.95515764 -0.80434823
# ...

# %%
print(neutraj_train[0])
print(neutraj_val[0])
print(neutraj_test[0])
# Out:
# [ 0.1023584  -0.08585469 -0.00114898  0.03741423  0.00099763  0.08788349
#  -0.03902316  0.03881962  0.0486323  -0.12247039  0.11439062 -0.02112702
#  -0.05041612  0.06260572  0.02906557  0.07532832  0.0286352  -0.05420483
#  -0.00353556 -0.00912727 -0.07822325 -0.09129388 -0.04364922  0.11500007
#  -0.04292895  0.04703898 -0.04201504 -0.01913443  0.0694371  -0.0547138
#   0.07704243  0.06956425 -0.07508922  0.00492162 -0.04108708 -0.08474641
#  -0.05261837  0.0269061   0.09223079 -0.09871102 -0.09595373  0.04446818
#   0.07679637 -0.07132458  0.05841944  0.13961281  0.14619806 -0.09574145
#   0.06921113 -0.09449717  0.1237242   0.12100961  0.06310601  0.06669459
#   0.03203087  0.05551917  0.14349088  0.0378757  -0.07507166  0.05629662
#   0.07387426 -0.08649812  0.10956531 -0.0687932   0.086119   -0.05620119
#  -0.03345842 -0.07011922  0.13991877 -0.02699289  0.03390564  0.03901921
#  -0.09722119 -0.05174578 -0.08150271 -0.03894968 -0.06158628  0.05399491
# ...
