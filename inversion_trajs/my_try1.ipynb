# %%
import numpy as np
import os, pickle, h5py

# %%
print(os.getcwd())
# Out:
# /home/yangshuaiyu6791/RepresentAttack/inversion-attack-new

# %%
# Load the data
with open('./experiment/vocab2hotcell_t2vec_partition','r' ) as v2h:
    for line in v2h:
        print(line)
# Out:
# 4 182673
#
# 5 184608
#
# 6 183965
#
# 7 185926
#
# 8 185281
#
# 9 184610
#
# 10 184595
#
# 11 189106
#
# 12 183317
#
# 13 194264
#
# 14 182671
#
# 15 182028
#
# 16 196185
#
# 17 185898
#
# 18 190414
#
# 19 183310
#
# 20 188479
#
# 21 178153
#
# 22 269682
#
# 23 182677
#
# 24 178154
#
# 25 185237
#
# 26 189099
#
# 27 190369
#
# 28 183952
#
# 29 181388
#
# 30 184607
#
# 31 189105
#
# 32 184609
#
# 33 189101
#
# 34 184598
#
# 35 270327
#
# 36 188461
#
# 37 184596
#
# 38 186547
#
# 39 187189
#
# 40 183967
#
# 41 182670
#
# 42 182021
#
# 43 185267
#
# 44 185256
#
# 45 193618
#
# 46 182672
#
# 47 218160
#
# 48 185925
#
# 49 187834
#
# 50 189103
#
# 51 196864
#
# 52 199424
#
# 53 198152
#
# 54 187192
#
# 55 189769
#
# 56 184594
#
# 57 198161
#
# 58 183319
#
# 59 196184
#
# 60 190410
#
# 61 183958
#
# 62 187816
#
# 63 209124
#
# 64 185251
#
# 65 194907
#
# 66 187852
#
# 67 196826
#
# 68 182022
#
# 69 199427
#
# 70 197464
#
# 71 183318
#
# 72 185266
#
# 73 183955
#
# 74 182668
#
# 75 191692
# ...
